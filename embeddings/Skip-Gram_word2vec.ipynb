# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [06:11, 84.5KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import collections
counter = collections.Counter(int_words)

total_words = len(int_words)

# %%
frec = {}
for int_word in int_words:
    frec[int_word] = counter[int_word]/total_words

# %%
total_words
# Out:
# 16680599

# %%
np.min(frec)
# Out:
# {0: 0.06363056866243233,
#  1: 0.035590868169662254,
#  2: 0.02497686084294695,
#  3: 0.02468520465002486,
#  4: 0.022313407330276328,
#  5: 0.01953604903516954,
#  6: 0.018966704972645167,
#  7: 0.015885220908433802,
#  8: 0.015013249823942174,
#  9: 0.011548985740859786,
#  10: 0.010980001377648369,
#  11: 0.007902294156223047,
#  12: 0.007510821403955577,
#  13: 0.007100764187185364,
#  14: 0.006996751135855493,
#  15: 0.006941537291316697,
#  16: 0.0068807481074270775,
#  17: 0.006762766732777402,
#  18: 0.006704255644536506,
#  19: 0.0065651119603079,
#  20: 0.0064854985123735664,
#  21: 0.006123581053654009,
#  22: 0.0059759844355709284,
#  23: 0.005731388902760626,
#  24: 0.005470427051210811,
#  25: 0.004587784887101477,
#  26: 0.004396364902723217,
#  27: 0.004368608105740087,
#  28: 0.0041332448552956645,
#  29: 0.003753042681500826,
#  30: 0.0037123966591367614,
#  31: 0.003673788932879449,
#  32: 0.0035269716633077744,
#  33: 0.00328453432637521,
#  34: 0.003271824950650753,
#  35: 0.0032116952155015538,
#  36: 0.0026592570206861277,
#  37: 0.002639773307900993,
#  38: 0.0023807298526869448,
#  39: 0.0023432012243685013,
#  40: 0.0022700623640673815,
#  41: 0.0021197080512516367,
#  42: 0.0019443546361854272,
#  43: 0.0018898002403870508,
#  44: 0.0017725382643632881,
#  45: 0.0017271562010452981,
#  46: 0.0017117490804736688,
#  47: 0.0016882487253605221,
#  48: 0.0016845917823454662,
#  49: 0.0015724255465885846,
#  50: 0.0015720658472756284,
#  51: 0.0015324989228504323,
#  52: 0.0015298611278887527,
#  53: 0.0015217079434617425,
#  54: 0.001463556554533803,
#  55: 0.0014445524408326104,
#  56: 0.001438617402168831,
#  57: 0.0014250087781619834,
#  58: 0.0013630805464480023,
#  59: 0.0013612820498832207,
#  60: 0.0012664413310337357,
#  61: 0.0012363464885163896,
#  62: 0.0012280134544329013,
#  63: 0.0012275938052344524,
#  64: 0.0012236970626774255,
#  65: 0.0011908445254274142,
#  66: 0.001166804621344833,
#  67: 0.0011513975007732037,
#  68: 0.001145942061193366,
#  69: 0.001127477496461608,
#  70: 0.001076040494708853,
#  71: 0.0010539789368475317,
#  72: 0.0010500821942905048,
#  73: 0.0010417491602070165,
#  74: 0.0010332962263525428,
#  75: 0.0009684904001349112,
#  76: 0.0009508651338000512,
#  77: 0.0009434313479989538,
#  78: 0.0009336595166636402,
#  79: 0.0009065621684209302,
#  80: 0.0008953515398337913,
#  81: 0.0008942124920094296,
#  82: 0.000881023517201031,
#  83: 0.0008770068748730187,
#  84: 0.0008739494307128899,
#  85: 0.0008689136403315013,
#  86: 0.0008654964968584162,
#  87: 0.0008644773488050399,
#  88: 0.0008483508296074979,
#  89: 0.0008399578456385169,
#  90: 0.0008021294678926098,
#  957: 0.00011138688724547602,
#  958: 0.00011138688724547602,
#  959: 0.00011132693735998329,
#  960: 0.00011126698747449058,
#  961: 0.00011114708770350513,
#  962: 0.00011102718793251969,
#  963: 0.00011102718793251969,
#  964: 0.00011096723804702697,
#  965: 0.00011084733827604153,
#  966: 0.0001104876389630852,
#  967: 0.0001104876389630852,
#  968: 0.00011042768907759248,
#  969: 0.00011036773919209975,
#  970: 0.00011030778930660704,
#  971: 0.00011006798976463615,
#  972: 0.00010970829045167983,
#  973: 0.00010958839068069437,
#  974: 0.00010928864125323077,
#  975: 0.00010928864125323077,
#  976: 0.00010904884171125989,
#  977: 0.00010904884171125989,
#  978: 0.00010868914239830356,
#  979: 0.00010862919251281085,
#  980: 0.00010856924262731812,
#  981: 0.0001085092927418254,
#  982: 0.00010844934285633267,
#  983: 0.00010838939297083996,
#  984: 0.00010832944308534723,
#  985: 0.00010832944308534723,
#  986: 0.00010826949319985451,
#  987: 0.0001082095433143618,
#  988: 0.00010802969365788363,
#  989: 0.00010796974377239091,
#  990: 0.00010796974377239091,
#  991: 0.00010790979388689818,
#  992: 0.00010772994423042002,
#  993: 0.00010755009457394186,
#  994: 0.00010731029503197097,
#  995: 0.00010725034514647826,
#  996: 0.0001071304453754928,
#  997: 0.0001070704954900001,
#  998: 0.00010689064583352193,
#  999: 0.00010689064583352193,
#  ...}

# %%
np.max(frec)
# Out:
# 0.06363056866243233

# %%
t = 1e-05
prob_words = {int_word: 1 - np.sqrt(np.divide(t,frec[int_word])) for int_word in int_words}

# %%
np.min(prob_words)
# Out:
# {0: 0.98746376577740469,
#  1: 0.98323781193133519,
#  2: 0.97999073790717206,
#  3: 0.9798728800896066,
#  4: 0.97883018546630463,
#  5: 0.97737536238795875,
#  6: 0.97703829909505446,
#  7: 0.9749098434772655,
#  8: 0.97419150710880509,
#  9: 0.97057421364733043,
#  10: 0.96982141987906356,
#  11: 0.9644267615025448,
#  12: 0.96351147714751806,
#  13: 0.96247268826339005,
#  14: 0.96219477853599333,
#  15: 0.96204472263650453,
#  16: 0.96187743001877457,
#  17: 0.96154632989244049,
#  18: 0.96137889308882907,
#  19: 0.96097176318217992,
#  20: 0.96073294615313531,
#  21: 0.95958921707063671,
#  22: 0.95909322225651139,
#  23: 0.95822946278846788,
#  24: 0.95724475646993612,
#  25: 0.95331273030870545,
#  26: 0.95230716554740003,
#  27: 0.95215589262593403,
#  28: 0.95081253586052672,
#  29: 0.9483811590967528,
#  30: 0.94809934803293527,
#  31: 0.9478273496542321,
#  32: 0.946752525433321,
#  33: 0.94482236303063571,
#  34: 0.94471529837599,
#  35: 0.94420017490649355,
#  36: 0.93867750129023297,
#  37: 0.93845161192836102,
#  38: 0.93518956429284583,
#  39: 0.93467262506280524,
#  40: 0.93362858054996889,
#  41: 0.93131498849887417,
#  42: 0.92828462725810013,
#  43: 0.92725685893570531,
#  44: 0.92488923411459367,
#  45: 0.92390884227957237,
#  46: 0.92356716853581156,
#  47: 0.92303703602880982,
#  48: 0.92295354500200544,
#  561: 0.76074498633286847,
#  562: 0.76070392308470425,
#  563: 0.76012680853821368,
#  564: 0.759961150237072,
#  565: 0.75967042049155997,
#  566: 0.75942038097932474,
#  567: 0.75929506820807657,
#  568: 0.75916955941439523,
#  569: 0.75862341030871394,
#  570: 0.75837008514923587,
#  571: 0.75815837047193257,
#  572: 0.75815837047193257,
#  573: 0.75786103279808548,
#  574: 0.75777587754059028,
#  575: 0.75722016983201468,
#  576: 0.75717726449808109,
#  577: 0.75687628888038194,
#  578: 0.75683320093832995,
#  579: 0.75674695628264366,
#  580: 0.75674695628264366,
#  581: 0.75666061979590837,
#  582: 0.75635771656467332,
#  583: 0.75631435227075772,
#  584: 0.75618412033072502,
#  585: 0.75618412033072502,
#  586: 0.75579216814110417,
#  587: 0.75574850111673031,
#  588: 0.7557048106595553,
#  589: 0.7557048106595553,
#  590: 0.75526661265836093,
#  591: 0.75522266305086971,
#  592: 0.75491435139314489,
#  593: 0.7548260481481226,
#  594: 0.75473764938849808,
#  595: 0.75464915494195561,
#  596: 0.75464915494195561,
#  597: 0.75456056463574384,
#  598: 0.7544718782966745,
#  599: 0.75420524134385558,
#  600: 0.75411616913268531,
#  601: 0.75411616913268531,
#  602: 0.75407159669855361,
#  603: 0.75393773381829654,
#  604: 0.75384837036295105,
#  605: 0.75380365210849232,
#  606: 0.75362453506196025,
#  607: 0.75353482981051223,
#  608: 0.75348994042480366,
#  609: 0.75331013729398666,
#  610: 0.75326512500226894,
#  611: 0.75308482912508767,
#  612: 0.75303969336547938,
#  613: 0.75285890248721432,
#  614: 0.75285890248721432,
#  615: 0.75267771397496386,
#  616: 0.75249612636898444,
#  617: 0.7524506669373161,
#  618: 0.75231413820201942,
#  619: 0.75217738332173822,
#  620: 0.75208608745690686,
#  621: 0.75185740563303982,
#  622: 0.75181159328254021,
#  623: 0.7513981370661752,
#  624: 0.75130597696553625,
#  625: 0.75112134886064519,
#  626: 0.75112134886064519,
#  627: 0.7510288804750882,
#  628: 0.75075085568770816,
#  629: 0.75056498754531409,
#  630: 0.75023871531630215,
#  631: 0.74977038322550404,
#  632: 0.74972340498106971,
#  633: 0.74958231133365905,
#  634: 0.74911027003128727,
#  635: 0.74882576070157847,
#  636: 0.7485402812694476,
#  637: 0.74830163670712024,
#  638: 0.74825382620934022,
#  639: 0.74806231140507973,
#  640: 0.74806231140507973,
#  641: 0.74782230212078038,
#  642: 0.74767796688171173,
#  643: 0.74762980003329771,
#  644: 0.7474368564271584,
#  645: 0.74646545613553439,
#  646: 0.74646545613553439,
#  647: 0.74636769845159923,
#  648: 0.74587720814323588,
#  649: 0.7455321668548458,
#  650: 0.74543332519909067,
#  651: 0.74483784678358766,
#  652: 0.74478803474734612,
#  653: 0.74443853174552665,
#  654: 0.74443853174552665,
#  655: 0.74438848543774161,
#  656: 0.7438360284301313,
#  657: 0.74373519631775564,
#  658: 0.74368473558994908,
#  659: 0.74358372464438849,
#  660: 0.74322924359679599,
#  661: 0.74307687244913434,
#  662: 0.7429751408563332,
#  663: 0.7429751408563332,
#  664: 0.74272028223234698,
#  665: 0.74266921947154496,
#  666: 0.74261812629512003,
#  667: 0.74138268620219883,
#  668: 0.74133082270748352,
#  669: 0.74133082270748352,
#  670: 0.74112305626652297,
#  671: 0.74065374527726513,
#  672: 0.74054910688094666,
#  673: 0.74039191153594697,
#  674: 0.74018187259506463,
#  675: 0.74018187259506463,
#  676: 0.74012928315471127,
#  677: 0.74002400840182292,
#  678: 0.73981307449969991,
#  679: 0.739707414830167,
#  680: 0.73965453670160319,
#  681: 0.73949570874785742,
#  682: 0.73944270146452273,
#  683: 0.73938966181032739,
#  684: 0.73928348525746457,
#  685: 0.7391239768211646,
#  686: 0.73901747507221738,
#  687: 0.73875064898787723,
#  688: 0.73853659786551829,
#  689: 0.73848300282505897,
#  690: 0.73821453237434365,
#  691: 0.73810691244477167,
#  692: 0.73805305268326538,
#  693: 0.73658616004178756,
#  694: 0.73658616004178756,
#  695: 0.73625682400157133,
#  696: 0.73620181447422406,
#  697: 0.73620181447422406,
#  698: 0.73614677051211719,
#  699: 0.73609169207931024,
#  700: 0.73592624959649267,
#  701: 0.7357604955784538,
#  702: 0.73548354392039661,
#  703: 0.73526135450190111,
#  704: 0.73520571960678271,
#  705: 0.73520571960678271,
#  706: 0.73503860423489753,
#  707: 0.73498282875890553,
#  708: 0.7349270180451688,
#  709: 0.73487117205656749,
#  710: 0.73436696463830908,
#  711: 0.73425452736962882,
#  712: 0.73419825516727644,
#  713: 0.73408560343734797,
#  714: 0.73397280835419998,
#  715: 0.73391635696011193,
#  716: 0.73374678691016149,
#  717: 0.73352018838992161,
#  718: 0.73352018838992161,
#  719: 0.73317920320678565,
#  720: 0.73283690570004545,
#  721: 0.73277972793710078,
#  722: 0.73277972793710078,
#  723: 0.73249328743031272,
#  724: 0.73180205446254221,
#  725: 0.73145442250128156,
#  726: 0.73145442250128156,
#  727: 0.73116369428200911,
#  728: 0.73093043063229501,
#  729: 0.73087201978402894,
#  730: 0.73069655873297701,
#  731: 0.73063799540918661,
#  732: 0.73057939386284088,
#  733: 0.73046207593603674,
#  734: 0.73010920047522498,
#  735: 0.7300502530464289,
#  736: 0.72999126697624961,
#  737: 0.72963653671639928,
#  738: 0.72939927167443752,
#  739: 0.72922091239219688,
#  740: 0.72904219996204489,
#  741: 0.72898255047314664,
#  742: 0.7287435579668049,
#  743: 0.72868371098493312,
#  744: 0.7283237953427073,
#  745: 0.72808305430773546,
#  746: 0.72802276898481488,
#  747: 0.72784167215128848,
#  748: 0.72778122610326967,
#  749: 0.72766021308377971,
#  750: 0.72766021308377971,
#  751: 0.72759964602266924,
#  752: 0.72729620340438261,
#  753: 0.72717454210161137,
#  754: 0.72686967502929178,
#  755: 0.72656378365224139,
#  756: 0.72656378365224139,
#  757: 0.72631832918957806,
#  758: 0.72607221252940035,
#  759: 0.72601057954685178,
#  760: 0.72601057954685178,
#  761: 0.72576363094291108,
#  762: 0.72570178938861107,
#  763: 0.72563990597877437,
#  764: 0.72557798066616519,
#  765: 0.72501875939695415,
#  868: 0.71170830285844622,
#  869: 0.71156455231491256,
#  870: 0.71120423306426384,
#  871: 0.7108425600772883,
#  872: 0.71077006228501882,
#  873: 0.71062490295958669,
#  874: 0.71047952485594701,
#  875: 0.71040675359046601,
#  876: 0.70982260121387863,
#  877: 0.70974933334279922,
#  878: 0.7095291962867647,
#  879: 0.7095291962867647,
#  880: 0.7095291962867647,
#  881: 0.70923489955098074,
#  882: 0.70908741534142139,
#  883: 0.70879177239453828,
#  884: 0.70871772071435712,
#  885: 0.70819777233292913,
#  886: 0.70819777233292913,
#  887: 0.70812326646482693,
#  888: 0.70812326646482693,
#  889: 0.70804870349681148,
#  890: 0.70782467126292081,
#  891: 0.7076750295994676,
#  892: 0.70752515777706049,
#  893: 0.70737505520509403,
#  894: 0.70714946739454132,
#  895: 0.70714946739454132,
#  896: 0.70714946739454132,
#  897: 0.70707415543943097,
#  898: 0.70707415543943097,
#  899: 0.70707415543943097,
#  900: 0.70684787047361797,
#  901: 0.70684787047361797,
#  902: 0.70677232553497793,
#  903: 0.70662106028144789,
#  904: 0.70662106028144789,
#  905: 0.70662106028144789,
#  906: 0.7064695606897764,
#  907: 0.70639372282794755,
#  908: 0.70631782615428174,
#  909: 0.70601364981811776,
#  910: 0.70578489630132624,
#  911: 0.70570852638344062,
#  912: 0.70555560796646166,
#  913: 0.70555560796646166,
#  914: 0.70540245092513798,
#  915: 0.70532578272629287,
#  916: 0.70517226658288945,
#  917: 0.70509541848216639,
#  918: 0.70494154183119573,
#  919: 0.7048645131239264,
#  920: 0.70478742405721373,
#  921: 0.7047102745521876,
#  922: 0.70463306452983321,
#  923: 0.70455579391099132,
#  924: 0.70424610388247744,
#  925: 0.70409089322045926,
#  926: 0.70401319619751612,
#  927: 0.70401319619751612,
#  928: 0.70393543793956037,
#  929: 0.70393543793956037,
#  930: 0.70385761836611482,
#  931: 0.70370179495010521,
#  932: 0.70362379094584482,
#  933: 0.70346759793945357,
#  934: 0.70338940877473,
#  935: 0.70338940877473,
#  936: 0.70331115772700925,
#  937: 0.70331115772700925,
#  938: 0.70307603246838668,
#  939: 0.70291897137962922,
#  940: 0.70276166078951019,
#  941: 0.70268291172488562,
#  942: 0.70268291172488562,
#  943: 0.70236728840005025,
#  944: 0.70220909933142772,
#  945: 0.70212991015287907,
#  946: 0.70149411414699225,
#  947: 0.70141435305382449,
#  948: 0.70133452798972051,
#  949: 0.70117468560631624,
#  950: 0.70101458631039781,
#  951: 0.70093444010504735,
#  952: 0.70085422941300701,
#  953: 0.70069361422259613,
#  954: 0.70061320955068829,
#  955: 0.70053274004501553,
#  956: 0.70045220561840038,
#  957: 0.70037160618350125,
#  958: 0.70037160618350125,
#  959: 0.70029094165281203,
#  960: 0.70021021193866173,
#  961: 0.70004855660846621,
#  962: 0.69988663948823038,
#  963: 0.69988663948823038,
#  964: 0.69980558253590508,
#  965: 0.69964327140349214,
#  966: 0.69915475376661462,
#  967: 0.69915475376661462,
#  968: 0.69907310218518626,
#  969: 0.69899138408515582,
#  970: 0.69890959937615738,
#  971: 0.69858179263712761,
#  972: 0.69808806878884311,
#  973: 0.69792295423933259,
#  974: 0.69750897974639847,
#  975: 0.69750897974639847,
#  976: 0.69717657193153659,
#  977: 0.69717657193153659,
#  978: 0.69667589907150207,
#  979: 0.69659221191280429,
#  980: 0.6965084554479688,
#  981: 0.69642462958128193,
#  982: 0.69634073421684528,
#  983: 0.69625676925857438,
#  984: 0.69617273461019891,
#  985: 0.69617273461019891,
#  986: 0.69608863017526201,
#  987: 0.6960044558571199,
#  988: 0.69575151263420731,
#  989: 0.69566705781304816,
#  990: 0.69566705781304816,
#  991: 0.69558253262264258,
#  992: 0.69532853385723759,
#  993: 0.69507389823724197,
#  994: 0.69473338880477842,
#  995: 0.69464808305735526,
#  996: 0.69447725679675232,
#  997: 0.69439173608319404,
#  998: 0.69413474240309125,
#  999: 0.69413474240309125,
#  ...}

# %%
np.max(prob_words)
# Out:
# 0.98746376577740469

# %%
import random
random.uniform(-3, 1)
# Out:
# -1.1518197513817543

# %%
train_words = [int_word for int_word in int_words if(prob_words[int_word]>random.random()) ]

# %%
[int_to_vocab[int_word] for int_word in train_words]
# Out:
# ['as',
#  'a',
#  'term',
#  'of',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'including',
#  'the',
#  'of',
#  'the',
#  'english',
#  'and',
#  'the',
#  'of',
#  'the',
#  'french',
#  'whilst',
#  'the',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'by',
#  'self',
#  'defined',
#  'the',
#  'word',
#  'is',
#  'from',
#  'the',
#  'greek',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'that',
#  'are',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'of',
#  'this',
#  'means',
#  'also',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'the',
#  'of',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'as',
#  'use',
#  'it',
#  'does',
#  'not',
#  'or',
#  'but',
#  'rather',
#  'a',
#  'anti',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'political',
#  'structures',
#  'and',
#  'economic',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'association',
#  'of',
#  'individuals',
#  'aid',
#  'and',
#  'while',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'also',
#  'positive',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'society',
#  'might',
#  'considerably',
#  'especially',
#  'with',
#  'to',
#  'there',
#  'is',
#  'also',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'was',
#  'on',
#  'principles',
#  'most',
#  'and',
#  'in',
#  'that',
#  'hunter',
#  'bands',
#  'were',
#  'and',
#  'division',
#  'of',
#  'labour',
#  'wealth',
#  'or',
#  'law',
#  'and',
#  'had',
#  'to',
#  'resources',
#  'william',
#  'anarchists',
#  'including',
#  'the',
#  'and',
#  'find',
#  'in',
#  'from',
#  'ancient',
#  'china',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'of',
#  'according',
#  'to',
#  'the',
#  'of',
#  'the',
#  'state',
#  'its',
#  'and',
#  'and',
#  'the',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'of',
#  'modern',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'at',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'they',
#  'at',
#  'the',
#  'or',
#  'were',
#  'an',
#  'early',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'of',
#  'modern',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'was',
#  'de',
#  'in',
#  'his',
#  'l',
#  'am',
#  'one',
#  'seven',
#  'zero',
#  'where',
#  'he',
#  'described',
#  'the',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'or',
#  'property',
#  'as',
#  'being',
#  'in',
#  'russell',
#  'a',
#  'libertarian',
#  'and',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'an',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'did',
#  'not',
#  'use',
#  'the',
#  'many',
#  'later',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'text',
#  'and',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'by',
#  'the',
#  'at',
#  'more',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'joseph',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  't',
#  'until',
#  'published',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'the',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'as',
#  'the',
#  'of',
#  'modern',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'property',
#  'is',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'of',
#  't',
#  'where',
#  'have',
#  'complete',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'such',
#  'as',
#  'workers',
#  'for',
#  'in',
#  'its',
#  'place',
#  'supported',
#  'he',
#  'called',
#  'possession',
#  'can',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'with',
#  'principles',
#  'of',
#  'and',
#  's',
#  'vision',
#  'of',
#  'which',
#  'called',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'of',
#  'their',
#  'using',
#  'labor',
#  'which',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'one',
#  'would',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'could',
#  'together',
#  'in',
#  'an',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'production',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  's',
#  'philosophy',
#  'of',
#  'is',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  's',
#  'in',
#  'his',
#  'the',
#  'and',
#  'its',
#  'own',
#  'that',
#  'most',
#  'commonly',
#  'including',
#  'the',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'in',
#  'general',
#  'and',
#  'the',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'or',
#  'in',
#  'the',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'he',
#  'advocated',
#  'and',
#  'a',
#  'form',
#  'of',
#  'in',
#  'which',
#  'would',
#  'in',
#  'of',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'about',
#  'through',
#  'might',
#  'how',
#  'to',
#  'take',
#  'to',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'property',
#  'and',
#  'what',
#  'i',
#  'in',
#  'power',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'as',
#  'i',
#  'am',
#  'the',
#  'of',
#  'the',
#  'thing',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'although',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'american',
#  'benjamin',
#  'in',
#  'one',
#  'eight',
#  'two',
#  'five',
#  'had',
#  'in',
#  'a',
#  'by',
#  'robert',
#  'called',
#  'new',
#  'which',
#  'in',
#  'a',
#  'few',
#  'years',
#  'much',
#  'internal',
#  'warren',
#  'the',
#  's',
#  'failure',
#  'on',
#  'a',
#  'of',
#  'a',
#  'of',
#  'private',
#  'property',
#  'to',
#  'which',
#  'what',
#  'he',
#  'called',
#  'the',
#  'of',
#  'the',
#  'individual',
#  'at',
#  'and',
#  'modern',
#  'in',
#  'one',
#  'eight',
#  'three',
#  'three',
#  'wrote',
#  'and',
#  'published',
#  'the',
#  'peaceful',
#  'which',
#  'some',
#  'have',
#  'to',
#  'be',
#  'the',
#  'first',
#  'ever',
#  'published',
#  'benjamin',
#  'says',
#  'that',
#  'was',
#  'the',
#  'first',
#  'man',
#  'to',
#  'and',
#  'the',
#  'doctrine',
#  'now',
#  'known',
#  'as',
#  'anarchism',
#  'xiv',
#  'december',
#  'one',
#  'nine',
#  'zero',
#  'zero',
#  'one',
#  'became',
#  'interested',
#  'in',
#  'through',
#  'and',
#  'edited',
#  'and',
#  'liberty',
#  'from',
#  'august',
#  'one',
#  'eight',
#  'eight',
#  'one',
#  'to',
#  'april',
#  'one',
#  'nine',
#  'zero',
#  'eight',
#  'is',
#  'widely',
#  'considered',
#  'to',
#  'be',
#  'the',
#  'ever',
#  'in',
#  'the',
#  'english',
#  'language',
#  's',
#  'of',
#  'incorporated',
#  'the',
#  'of',
#  'a',
#  'variety',
#  'of',
#  'ideas',
#  'on',
#  's',
#  'ideas',
#  'on',
#  'cost',
#  'as',
#  'the',
#  'limit',
#  'of',
#  'price',
#  'a',
#  'variety',
#  'of',
#  'labour',
#  'theory',
#  'of',
#  'value',
#  's',
#  'market',
#  's',
#  'and',
#  's',
#  'of',
#  'equal',
#  'freedom',
#  'supported',
#  'the',
#  's',
#  'right',
#  'to',
#  'own',
#  'the',
#  'product',
#  'of',
#  'his',
#  'or',
#  'her',
#  'labour',
#  'as',
#  'property',
#  'and',
#  'believed',
#  'in',
#  'a',
#  'economy',
#  'for',
#  'trading',
#  'this',
#  'he',
#  'that',
#  'in',
#  'a',
#  'free',
#  'market',
#  'system',
#  'without',
#  'the',
#  'state',
#  'the',
#  'of',
#  'competition',
#  'would',
#  'profits',
#  'and',
#  'ensure',
#  'that',
#  'all',
#  'workers',
#  'received',
#  'the',
#  'value',
#  'of',
#  'their',
#  'other',
#  'one',
#  'nine',
#  'th',
#  'century',
#  'included',
#  'stephen',
#  'pearl',
#  'and',
#  'victor',
#  'the',
#  'first',
#  'international',
#  'one',
#  'eight',
#  'one',
#  'four',
#  'one',
#  'eight',
#  'seven',
#  'six',
#  'in',
#  'europe',
#  'followed',
#  'the',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'twenty',
#  'years',
#  'later',
#  'one',
#  'eight',
#  'six',
#  'four',
#  'international',
#  's',
#  'sometimes',
#  'the',
#  'first',
#  'international',
#  'united',
#  'some',
#  'diverse',
#  'european',
#  'including',
#  'due',
#  'to',
#  'its',
#  'links',
#  'to',
#  'movements',
#  'the',
#  'international',
#  'became',
#  'from',
#  'the',
#  'karl',
#  'marx',
#  'was',
#  'a',
#  'figure',
#  'in',
#  'the',
#  'international',
#  'he',
#  'was',
#  'to',
#  ...]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    
    R = random.randrange(1,window_size)
    
    lower_bound = idx-R if idx-R > 0 else 0  
    upper_bound = idx+R if idx+R < len(words)-1 else len(words)-1
    #para que no haya duplicados se pasa por set primero
    return list(set(words[lower_bound:idx]+words[idx+1:upper_bound+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32,shape=[None,None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1,1))   # create embedding weight matrix here
    #obtiene las filas correspondientes a los inputs(una lista de integers que contiene int_word's)
    embed = tf.nn.embedding_lookup(embedding,inputs)  # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=[n_vocab,n_embedding],stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(shape=[n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 8.7831 0.2886 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.5010 0.2722 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.2411 0.2718 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5131 0.2725 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.1732 0.2744 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.8646 0.2741 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.6398 0.2691 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.4551 0.3014 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.5660 0.2778 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.5018 0.2838 sec/batch
# Nearest to most: recognition, one, gives, standard, another, president, version, me,
# Nearest to three: millennium, engineering, appointed, site, withholding, spring, allowed, approximately,
# Nearest to no: be, we, in, question, destruction, said, under, consider,
# Nearest to over: lead, century, allah, certain, opposed, absinthium, retreat, teaching,
# Nearest to b: projects, doctors, above, really, suppressant, mark, contest, states,
# Nearest to in: at, wife, master, no, purchase, independent, canadian, supported,
# Nearest to other: generation, terms, cornell, east, if, show, whose, claude,
# Nearest to however: wrong, requirement, clicked, ayyash, although, massive, apparently, baseball,
# Nearest to pre: yet, passage, moderate, will, political, gene, hand, europe,
# Nearest to joseph: earlier, women, risk, previously, subsequent, readme, friends, k,
# Nearest to additional: kg, generally, appeared, honor, engineering, ground, forced, ask,
# Nearest to placed: thro, response, object, internet, press, paglia, wpa, rugby,
# Nearest to stage: mission, gdp, are, counters, look, northern, affairs, cause,
# Nearest to quite: author, politician, gop, industries, wales, hearsay, roman, greeks,
# Nearest to issue: call, didn, will, km, amf, ietf, song, iv,
# Nearest to running: functions, sequenced, organization, built, narayan, antonio, nazi, actually,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.4511 0.2980 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.3858 0.2763 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.3404 0.2980 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.3402 0.3089 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.3332 0.2974 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.3245 0.2929 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.3315 0.2996 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.2576 0.2956 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.2827 0.2945 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.2861 0.2862 sec/batch
# Nearest to most: recognition, one, gives, me, standard, not, another, look,
# Nearest to three: millennium, approximately, engineering, appointed, spring, isbn, withholding, reactions,
# Nearest to no: be, we, in, question, destruction, abuse, said, hypothesis,
# Nearest to over: century, allah, lead, footballer, complicated, certain, grounds, couple,
# Nearest to b: projects, doctors, contest, pressed, really, frank, suppressant, philosopher,
# Nearest to in: at, purchase, wife, master, no, nominal, socialist, twice,
# Nearest to other: generation, claude, terms, cornell, practiced, if, east, whose,
# Nearest to however: requirement, appropriate, wrong, improvements, cancer, millions, although, creating,
# Nearest to pre: yet, moderate, passage, automatically, investigation, gene, political, disks,
# Nearest to joseph: earlier, risk, owing, subsequent, women, declaration, ben, friends,
# Nearest to additional: kg, computers, generally, engineering, honor, appeared, ask, masses,
# Nearest to placed: thro, response, rugby, easy, fleet, submarine, ordinary, mp,
# Nearest to stage: gdp, look, mission, officers, finance, grown, mode, are,
# Nearest to quite: author, industries, politician, israeli, wales, gop, decline, dih,
# Nearest to issue: didn, call, song, km, exercise, will, act, particularly,
# Nearest to running: functions, shared, antonio, sequenced, organization, nazi, built, honour,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.2554 0.2887 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.2305 0.2928 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.1865 0.2889 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.1902 0.2839 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.2374 0.2881 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.2167 0.3102 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.1862 0.2778 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.2213 0.2920 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.2037 0.2853 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.0904 0.2854 sec/batch
# Nearest to most: recognition, gives, beneath, macedonia, tea, one, standard, these,
# Nearest to three: millennium, approximately, engineering, isbn, appointed, withholding, spring, attendance,
# Nearest to no: we, be, question, in, accordance, abuse, hypothesis, formula,
# Nearest to over: century, footballer, couple, allah, lead, plague, years, every,
# Nearest to b: projects, doctors, contest, pressed, really, judges, philosopher, grainger,
# Nearest to in: at, purchase, wife, nominal, metropolitan, socialist, master, no,
# Nearest to other: claude, terms, generation, cornell, practiced, east, with, through,
# Nearest to however: requirement, appropriate, improvements, although, trains, wrong, millions, cancer,
# Nearest to pre: yet, moderate, automatically, gene, passage, investigation, radical, political,
# Nearest to joseph: owing, risk, subsequent, ben, women, declaration, earlier, friends,
# Nearest to additional: kg, computers, generally, honor, appeared, engineering, ask, sale,
# Nearest to placed: thro, response, rugby, easy, submarine, fleet, mp, mixed,
# Nearest to stage: gdp, look, mission, finance, grown, officers, hearing, fiber,
# Nearest to quite: author, gop, dih, industries, israeli, politician, wales, decline,
# Nearest to issue: didn, call, exercise, km, will, song, particularly, act,
# Nearest to running: antonio, functions, shared, sequenced, monster, nazi, honour, built,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.2396 0.2834 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.1700 0.2927 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.1769 0.2877 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.1802 0.2823 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.1791 0.2774 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.1411 0.2839 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.1736 0.2804 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.1735 0.2849 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.1616 0.2863 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.1416 0.2976 sec/batch
# Nearest to most: recognition, beneath, tea, noise, these, others, standard, scripture,
# Nearest to three: approximately, millennium, attendance, engineering, isbn, withholding, spring, appointed,
# Nearest to no: we, be, question, accordance, hypothesis, in, abuse, said,
# Nearest to over: century, footballer, couple, allah, every, years, plague, up,
# Nearest to b: projects, doctors, pressed, contest, really, columbus, facts, philosopher,
# Nearest to in: at, purchase, nominal, wife, metropolitan, no, socialist, trains,
# Nearest to other: terms, claude, generation, with, mice, cornell, east, practiced,
# Nearest to however: requirement, appropriate, although, trains, wrong, cancer, millions, improvements,
# Nearest to pre: yet, moderate, nervous, passage, political, gene, radical, investigation,
# Nearest to joseph: owing, risk, women, ben, declaration, subsequent, readme, friends,
# Nearest to additional: kg, computers, generally, honor, engineering, appeared, ask, persia,
# Nearest to placed: thro, rugby, response, submarine, easy, fleet, ordinary, mixed,
# Nearest to stage: gdp, mission, look, finance, reasonable, grown, hearing, officers,
# Nearest to quite: author, gop, dih, industries, decline, if, israeli, wales,
# Nearest to issue: didn, call, exercise, will, km, song, toll, amf,
# Nearest to running: antonio, functions, sequenced, monster, shared, built, voices, sample,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.1262 0.2980 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.1387 0.2855 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.1469 0.2982 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.1595 0.2832 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.1268 0.2885 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.1104 0.2865 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.0687 0.2832 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.1393 0.2851 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.1051 0.2888 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.1061 0.2852 sec/batch
# Nearest to most: recognition, beneath, noise, tea, others, these, macedonia, scripture,
# Nearest to three: approximately, millennium, attendance, engineering, withholding, landed, vieri, appointed,
# Nearest to no: we, question, accordance, be, hypothesis, said, drivers, in,
# Nearest to over: allah, century, footballer, up, couple, every, suburbs, bobby,
# Nearest to b: projects, philosopher, doctors, pressed, william, painter, columbus, frank,
# Nearest to in: at, purchase, nominal, wife, metropolitan, holland, twice, master,
# Nearest to other: terms, generation, claude, with, or, east, cornell, mice,
# Nearest to however: requirement, appropriate, although, wrong, trains, improvements, cancer, millions,
# Nearest to pre: yet, moderate, nervous, radical, passage, political, gene, disks,
# Nearest to joseph: ben, owing, metro, women, risk, excessive, readme, singles,
# Nearest to additional: kg, computers, generally, engineering, honor, talmud, appeared, sale,
# Nearest to placed: thro, response, rugby, submarine, easy, fleet, ordinary, relationships,
# Nearest to stage: gdp, mission, look, reasonable, finance, hearing, grown, fiber,
# Nearest to quite: gop, dih, industries, author, decline, if, greeks, take,
# Nearest to issue: didn, call, exercise, km, song, toll, will, particularly,
# Nearest to running: antonio, voices, monster, functions, shared, sequenced, sample, built,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.1309 0.2901 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.1419 0.2839 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.1057 0.2852 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.1350 0.2939 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.0966 0.2815 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.1210 0.2902 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.1215 0.2942 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.1160 0.2765 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.1061 0.2935 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.1062 0.2808 sec/batch
# Nearest to most: recognition, beneath, others, tea, allegiance, macedonia, these, noise,
# Nearest to three: approximately, millennium, spring, attendance, landed, withholding, nd, engineering,
# Nearest to no: accordance, we, question, hypothesis, said, be, formula, in,
# Nearest to over: allah, footballer, up, century, every, couple, suburbs, bobby,
# Nearest to b: projects, doctors, columbus, philosopher, pressed, grainger, calligraphy, contest,
# Nearest to in: at, purchase, nominal, metropolitan, wife, public, twice, holland,
# Nearest to other: terms, generation, with, epistle, east, mice, or, practiced,
# Nearest to however: although, requirement, appropriate, wrong, trains, since, animation, universal,
# Nearest to pre: yet, moderate, nervous, md, radical, passage, political, gene,
# Nearest to joseph: ben, owing, friends, women, readme, charted, metro, singles,
# Nearest to additional: kg, computers, generally, engineering, sale, ask, honor, appeared,
# Nearest to placed: thro, response, rugby, submarine, relationships, easy, ordinary, fleet,
# Nearest to stage: look, mission, gdp, grown, reasonable, finance, hearing, han,
# Nearest to quite: gop, dih, eleanor, decline, industries, author, if, mentioned,
# Nearest to issue: didn, call, exercise, toll, will, km, song, began,
# Nearest to running: antonio, monster, sequenced, voices, shared, sample, cubic, throw,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.1308 0.2954 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.0573 0.2723 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.0702 0.2907 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.0732 0.2808 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.1368 0.2855 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.0942 0.2928 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.1318 0.2759 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.1241 0.3146 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.0860 0.3295 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.0881 0.2711 sec/batch
# Nearest to most: recognition, beneath, others, allegiance, macedonia, tea, parks, these,
# Nearest to three: approximately, millennium, attendance, withholding, spring, landed, range, sr,
# Nearest to no: accordance, we, question, hypothesis, formula, drivers, be, said,
# Nearest to over: allah, up, every, century, hours, footballer, years, suburbs,
# Nearest to b: projects, philosopher, pressed, doctors, columbus, grainger, calligraphy, pirates,
# Nearest to in: at, purchase, nominal, turkish, wife, metropolitan, twice, master,
# Nearest to other: terms, generation, east, epistle, with, practiced, or, claude,
# Nearest to however: although, requirement, appropriate, trains, wrong, since, detective, beauty,
# Nearest to pre: yet, radical, md, moderate, political, nervous, automatically, discharging,
# Nearest to joseph: ben, owing, metro, friends, women, readme, singles, charted,
# Nearest to additional: kg, computers, engineering, sale, generally, honor, talmud, related,
# Nearest to placed: thro, rugby, response, relationships, submarine, metabolism, fleet, ordinary,
# Nearest to stage: mission, look, grown, gdp, han, hearing, reasonable, finance,
# Nearest to quite: gop, dih, eleanor, decline, author, if, mentioned, industries,
# Nearest to issue: didn, call, exercise, will, song, increase, toll, km,
# Nearest to running: antonio, monster, sequenced, shared, voices, throw, built, cubic,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.1003 0.2768 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.0789 0.2950 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.1163 0.3484 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.1172 0.3232 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.0830 0.2987 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.0943 0.2856 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.1093 0.2926 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.1071 0.2846 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.0719 0.2891 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.1074 0.2921 sec/batch
# Nearest to most: recognition, others, allegiance, beneath, tea, macedonia, these, scripture,
# Nearest to three: approximately, millennium, withholding, attendance, spring, allowed, vieri, range,
# Nearest to no: accordance, question, we, hypothesis, formula, drivers, be, said,
# Nearest to over: allah, up, every, hours, century, footballer, years, wakizashi,
# Nearest to b: projects, pirates, doctors, philosopher, columbus, pressed, grainger, calligraphy,
# Nearest to in: at, purchase, nominal, holland, twice, metropolitan, turkish, nickname,
# Nearest to other: terms, generation, epistle, east, with, or, canonical, population,
# Nearest to however: although, requirement, appropriate, since, trains, wrong, detective, universal,
# Nearest to pre: yet, md, discharging, radical, moderate, political, nervous, ois,
# Nearest to joseph: ben, owing, friends, women, reserved, charted, subsequent, readme,
# Nearest to additional: kg, computers, generally, engineering, sale, talmud, ask, symbols,
# Nearest to placed: thro, submarine, rugby, response, metabolism, fleet, pressure, while,
# Nearest to stage: mission, look, gdp, grown, han, reasonable, hearing, finance,
# Nearest to quite: gop, dih, eleanor, author, boy, greeks, mentioned, belgrade,
# Nearest to issue: didn, call, exercise, toll, km, began, will, harm,
# Nearest to running: antonio, sequenced, monster, shared, voices, cubic, built, throw,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.0783 0.3033 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.1016 0.2958 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.0809 0.2915 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.0529 0.2847 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.1112 0.2763 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.0973 0.2798 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.0272 0.2978 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.0808 0.2946 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.0804 0.3061 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.0980 0.2729 sec/batch
# Nearest to most: recognition, allegiance, others, tea, beneath, leather, scripture, these,
# Nearest to three: approximately, millennium, attendance, withholding, spring, sr, range, allowed,
# Nearest to no: accordance, question, we, hypothesis, formula, said, drivers, stops,
# Nearest to over: up, hours, every, allah, footballer, years, suburbs, century,
# Nearest to b: projects, pirates, doctors, calligraphy, grainger, philosopher, columbus, above,
# Nearest to in: at, purchase, nominal, holland, metropolitan, turkish, twice, trains,
# Nearest to other: terms, generation, or, epistle, east, with, canonical, population,
# Nearest to however: although, requirement, since, appropriate, trains, that, wrong, proved,
# Nearest to pre: md, discharging, moderate, radical, yet, political, nervous, jane,
# Nearest to joseph: ben, owing, friends, women, ought, reserved, charted, octave,
# Nearest to additional: computers, kg, sale, generally, engineering, talmud, symbols, soleil,
# Nearest to placed: thro, rugby, metabolism, response, submarine, relationships, pressure, fleet,
# Nearest to stage: mission, look, han, grown, gdp, reasonable, hearing, pipe,
# Nearest to quite: gop, dih, eleanor, boy, author, decline, greeks, belgrade,
# Nearest to issue: didn, call, exercise, toll, harm, will, increase, began,
# Nearest to running: sequenced, monster, shared, antonio, voices, built, throw, sample,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 3.7017 0.2720 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 3.9496 0.2739 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 3.8844 0.2689 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 3.9556 0.2732 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.0365 0.2723 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.0451 0.2734 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.0720 0.2735 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.0755 0.2727 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.0590 0.2746 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.0646 0.2733 sec/batch
# Nearest to most: recognition, others, allegiance, beneath, tea, macedonia, leather, these,
# Nearest to three: approximately, millennium, attendance, withholding, spring, range, sr, accepts,
# Nearest to no: accordance, question, we, hypothesis, said, formula, drivers, spitfire,
# Nearest to over: up, hours, allah, every, years, footballer, suburbs, century,
# Nearest to b: projects, philosopher, grainger, calligraphy, pirates, notebooks, painter, pressed,
# Nearest to in: at, purchase, metropolitan, twice, nominal, holland, turkish, nickname,
# Nearest to other: terms, or, generation, east, several, canonical, epistle, with,
# Nearest to however: although, requirement, since, appropriate, that, proved, universal, trains,
# Nearest to pre: md, discharging, nervous, moderate, yet, political, radical, jane,
# Nearest to joseph: ben, friends, owing, ought, women, arsenide, readme, octave,
# Nearest to additional: computers, kg, generally, sale, engineering, ask, talmud, symbols,
# Nearest to placed: thro, metabolism, submarine, rugby, pressure, response, relationships, fleet,
# Nearest to stage: han, look, mission, gdp, grown, reasonable, fiber, hearing,
# Nearest to quite: gop, dih, eleanor, boy, mentioned, belgrade, greeks, reval,
# Nearest to issue: didn, call, exercise, harm, toll, will, began, amf,
# Nearest to running: antonio, sequenced, shared, monster, throw, voices, built, cubic,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.1111 0.2796 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.0165 0.2731 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.0931 0.2763 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.0849 0.2735 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.0504 0.2696 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.0872 0.2713 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.0933 0.2741 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.0640 0.2726 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.0995 0.2740 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.0032 0.2724 sec/batch
# Nearest to most: recognition, macedonia, others, tea, parks, beneath, allegiance, scripture,
# Nearest to three: approximately, withholding, millennium, range, attendance, spring, sr, apricots,
# Nearest to no: accordance, question, hypothesis, we, said, spitfire, rajiv, formula,
# Nearest to over: years, hours, up, every, footballer, allah, beating, wakizashi,
# Nearest to b: projects, calligraphy, pirates, grainger, notebooks, philosopher, mindat, columbus,
# Nearest to in: at, purchase, metropolitan, twice, nominal, turkish, holland, commonly,
# Nearest to other: terms, generation, east, canonical, or, several, population, epistle,
# Nearest to however: although, requirement, since, that, proved, trains, appropriate, universal,
# Nearest to pre: discharging, yet, md, radical, political, nervous, moderate, though,
# Nearest to joseph: ben, owing, friends, ought, enlightenment, arsenide, readme, reserved,
# Nearest to additional: kg, computers, sale, soleil, engineering, beam, symbols, generally,
# Nearest to placed: thro, metabolism, pressure, submarine, rugby, fleet, response, relationships,
# Nearest to stage: look, han, grown, mission, reasonable, inspired, urged, ramp,
# Nearest to quite: gop, dih, eleanor, boy, mentioned, greeks, reval, originally,
# Nearest to issue: didn, call, exercise, harm, toll, began, animators, amf,
# Nearest to running: sequenced, monster, built, shared, antonio, throw, dressed, voices,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 3.9946 0.2764 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.0419 0.2727 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 3.9581 0.2716 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.0582 0.2732 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.0855 0.3130 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.0628 0.2903 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 3.9610 0.2786 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.0370 0.2733 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.0200 0.2966 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.0912 0.2845 sec/batch
# Nearest to most: others, recognition, tea, macedonia, beneath, allegiance, parks, leather,
# Nearest to three: approximately, withholding, millennium, attendance, sr, vieri, spring, disfellowshipped,
# Nearest to no: question, accordance, hypothesis, we, said, nothing, rajiv, spitfire,
# Nearest to over: hours, allah, up, years, every, wakizashi, disruptions, century,
# Nearest to b: philosopher, projects, calligraphy, painter, grainger, columbus, notebooks, william,
# Nearest to in: at, purchase, twice, metropolitan, turkish, holland, vast, nickname,
# Nearest to other: terms, generation, canonical, several, or, counting, mice, east,
# Nearest to however: although, requirement, since, that, proved, reliable, universal, wrong,
# Nearest to pre: discharging, radical, md, moderate, yet, political, nervous, genocide,
# Nearest to joseph: ben, ought, friends, arsenide, charted, reserved, readme, projectors,
# Nearest to additional: computers, kg, sale, soleil, engineering, ask, beam, instrument,
# Nearest to placed: thro, pressure, submarine, metabolism, rugby, fleet, hobo, relationships,
# Nearest to stage: han, look, mission, grown, urged, inspired, ramp, reasonable,
# Nearest to quite: gop, dih, eleanor, greeks, mentioned, originally, boy, reval,
# Nearest to issue: didn, call, exercise, harm, toll, animators, increase, amf,
# Nearest to running: sequenced, built, monster, throw, pc, shared, dressed, voices,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.0959 0.1268 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.0819 0.2828 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.0587 0.2853 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.0907 0.2902 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.0040 0.2862 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.0312 0.3022 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.0088 0.2886 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 3.8890 0.2874 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 3.9511 0.3635 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.0552 0.2968 sec/batch
# Nearest to most: recognition, others, allegiance, tea, macedonia, beneath, parks, scripture,
# Nearest to three: approximately, millennium, withholding, attendance, sr, vieri, disfellowshipped, allowed,
# Nearest to no: question, accordance, said, hypothesis, we, nothing, rajiv, spitfire,
# Nearest to over: hours, years, up, allah, wakizashi, every, disruptions, increasing,
# Nearest to b: philosopher, projects, painter, calligraphy, grainger, columbus, notebooks, william,
# Nearest to in: at, purchase, metropolitan, twice, turkish, holland, vast, public,
# Nearest to other: canonical, terms, generation, several, or, east, mice, colored,
# Nearest to however: although, requirement, since, that, proved, universal, trains, reliable,
# Nearest to pre: discharging, radical, yet, md, political, moderate, nervous, genocide,
# Nearest to joseph: ben, friends, arsenide, ought, projectors, enlightenment, bomis, readme,
# Nearest to additional: computers, kg, sale, soleil, ask, beam, working, instrument,
# Nearest to placed: thro, pressure, metabolism, submarine, rugby, fleet, hobo, ordinary,
# Nearest to stage: han, look, mission, grown, urged, tie, reasonable, ramp,
# Nearest to quite: gop, dih, greeks, originally, mentioned, boy, eleanor, wales,
# Nearest to issue: call, didn, exercise, toll, harm, increase, will, animators,
# Nearest to running: throw, built, sequenced, monster, dressed, shared, antonio, pc,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.0394 0.2880 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.0231 0.2843 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.0273 0.2735 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 3.9932 0.2772 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.0693 0.2850 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.0536 0.3194 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.0803 0.3053 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.0212 0.2968 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.0521 0.2920 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.0678 0.2784 sec/batch
# Nearest to most: recognition, others, macedonia, allegiance, parks, tea, beneath, leather,
# Nearest to three: approximately, withholding, millennium, range, sr, vieri, allowed, disfellowshipped,
# Nearest to no: accordance, question, nothing, said, hypothesis, we, rajiv, spitfire,
# Nearest to over: hours, years, up, wakizashi, every, suburbs, allah, increasing,
# Nearest to b: projects, calligraphy, philosopher, grainger, judges, notebooks, pressed, pirates,
# Nearest to in: at, purchase, metropolitan, twice, turkish, vast, nominal, public,
# Nearest to other: canonical, generation, terms, several, or, mice, colored, others,
# Nearest to however: although, requirement, since, that, proved, reliable, trains, universal,
# Nearest to pre: discharging, radical, yet, md, moderate, political, nervous, though,
# Nearest to joseph: ben, arsenide, projectors, friends, bomis, reserved, readme, bellows,
# Nearest to additional: computers, kg, sale, soleil, ask, instrument, beam, devices,
# Nearest to placed: thro, pressure, metabolism, submarine, fleet, standing, hobo, close,
# Nearest to stage: han, look, grown, mission, urged, forwarding, tie, classrooms,
# Nearest to quite: gop, dih, greeks, eleanor, originally, mentioned, author, hearsay,
# Nearest to issue: call, didn, exercise, harm, toll, amf, animators, increase,
# Nearest to running: pc, built, throw, sequenced, dressed, monster, shared, sample,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.0576 0.2870 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.0690 0.2862 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.0665 0.2881 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.0123 0.2868 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.0390 0.3075 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.0645 0.3118 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.0541 0.3087 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.0548 0.2859 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.0802 0.3585 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.0070 0.3234 sec/batch
# Nearest to most: macedonia, recognition, allegiance, others, tea, beneath, parks, among,
# Nearest to three: approximately, withholding, millennium, sr, range, disfellowshipped, vieri, attendance,
# Nearest to no: question, accordance, said, nothing, spitfire, we, rajiv, hypothesis,
# Nearest to over: hours, years, up, every, wakizashi, footballer, disruptions, allah,
# Nearest to b: projects, calligraphy, judges, grainger, philosopher, mindat, pirates, notebooks,
# Nearest to in: at, metropolitan, purchase, twice, nominal, holland, turkish, public,
# Nearest to other: or, generation, several, terms, canonical, baldwin, counting, others,
# Nearest to however: although, requirement, since, that, but, proved, reliable, paths,
# Nearest to pre: discharging, radical, yet, md, moderate, genocide, political, traditions,
# Nearest to joseph: ben, friends, arsenide, projectors, bomis, charted, bellows, enlightenment,
# Nearest to additional: computers, kg, sale, soleil, ask, beam, matches, instrument,
# Nearest to placed: thro, pressure, metabolism, submarine, fleet, hobo, litigant, lands,
# Nearest to stage: look, han, grown, mission, tie, forwarding, urged, carotenoid,
# Nearest to quite: dih, gop, greeks, author, mentioned, originally, eleanor, hearsay,
# Nearest to issue: call, exercise, didn, harm, increase, animators, telescope, amf,
# Nearest to running: pc, throw, dressed, sequenced, built, monster, shared, asr,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.0145 0.3572 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.0865 0.3245 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.0440 0.3268 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.0320 0.3134 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.0557 0.3263 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.0527 0.3131 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.0067 0.3352 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.0572 0.3459 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.0650 0.3430 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.0662 0.3340 sec/batch
# Nearest to most: allegiance, others, beneath, recognition, tea, leather, among, extremely,
# Nearest to three: approximately, withholding, sr, millennium, disfellowshipped, attendance, vieri, allowed,
# Nearest to no: question, accordance, nothing, said, we, spitfire, hypothesis, rajiv,
# Nearest to over: hours, wakizashi, up, every, years, disruptions, allah, footballer,
# Nearest to b: calligraphy, projects, grainger, mindat, judges, notebooks, pirates, philosopher,
# Nearest to in: at, purchase, twice, metropolitan, turkish, public, perfect, vast,
# Nearest to other: or, canonical, generation, several, colored, importantly, others, counting,
# Nearest to however: although, requirement, that, since, but, proved, paths, reliable,
# Nearest to pre: discharging, md, yet, radical, moderate, genocide, nervous, traditions,
# Nearest to joseph: ben, friends, arsenide, projectors, bomis, ought, bellows, charted,
# Nearest to additional: computers, soleil, sale, kg, ask, beam, instrument, matches,
# Nearest to placed: thro, pressure, metabolism, litigant, fleet, submarine, hobo, lands,
# Nearest to stage: look, han, grown, mission, tie, forwarding, urged, carotenoid,
# Nearest to quite: dih, gop, greeks, author, hearsay, corum, wales, eleanor,
# Nearest to issue: call, exercise, didn, harm, animators, amf, ietf, increase,
# Nearest to running: pc, built, throw, monster, sequenced, dressed, capability, rie,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.0494 0.3154 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.0422 0.3094 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.0558 0.3438 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.0586 0.3172 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.0233 0.2866 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.0230 0.3539 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 3.9835 0.3523 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.0400 0.3398 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.0331 0.3281 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 3.9979 0.3044 sec/batch
# Nearest to most: allegiance, recognition, others, leather, macedonia, beneath, among, danson,
# Nearest to three: approximately, withholding, sr, millennium, attendance, disfellowshipped, vieri, inadvertent,
# Nearest to no: question, accordance, nothing, said, spitfire, hypothesis, rajiv, we,
# Nearest to over: hours, up, wakizashi, every, allah, disruptions, years, suburbs,
# Nearest to b: philosopher, calligraphy, projects, grainger, notebooks, judges, william, painter,
# Nearest to in: at, twice, purchase, public, metropolitan, turkish, nominal, luis,
# Nearest to other: several, generation, counting, others, canonical, importantly, colored, or,
# Nearest to however: although, since, requirement, that, but, proved, paths, reliable,
# Nearest to pre: discharging, md, yet, radical, traditions, moderate, genocide, nervous,
# Nearest to joseph: ben, projectors, bomis, friends, arsenide, charted, enlightenment, reserved,
# Nearest to additional: computers, kg, soleil, sale, beam, instrument, devices, matches,
# Nearest to placed: thro, metabolism, pressure, litigant, submarine, fleet, hobo, lands,
# Nearest to stage: look, han, grown, forwarding, mission, urged, tie, single,
# Nearest to quite: greeks, dih, gop, hearsay, corum, boy, wales, eleanor,
# Nearest to issue: exercise, call, harm, didn, animators, ietf, amf, review,
# Nearest to running: pc, throw, monster, built, sample, rie, sequenced, dressed,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.0678 0.3070 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.0629 0.2869 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.0341 0.2754 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.0661 0.2771 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.0150 0.3301 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.0418 0.3302 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.0489 0.2994 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.0201 0.3015 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.0399 0.3173 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.0446 0.2941 sec/batch
# Nearest to most: allegiance, recognition, macedonia, others, beneath, tea, leather, danson,
# Nearest to three: approximately, withholding, sr, millennium, disfellowshipped, vieri, inadvertent, attendance,
# Nearest to no: question, accordance, nothing, said, spitfire, rajiv, hypothesis, teilhard,
# Nearest to over: hours, wakizashi, every, allah, up, disruptions, footballer, increasing,
# Nearest to b: calligraphy, projects, grainger, judges, pirates, mindat, notebooks, philosopher,
# Nearest to in: at, metropolitan, twice, purchase, public, turkish, sopot, throughout,
# Nearest to other: several, others, baldwin, generation, importantly, or, canonical, colored,
# Nearest to however: although, since, but, requirement, that, proved, though, argued,
# Nearest to pre: discharging, yet, radical, md, traditions, moderate, genocide, nervous,
# Nearest to joseph: ben, projectors, bomis, enlightenment, bellows, friends, arsenide, charted,
# Nearest to additional: computers, soleil, sale, kg, beam, matches, instrument, ask,
# Nearest to placed: thro, pressure, metabolism, litigant, submarine, fleet, hobo, lands,
# Nearest to stage: look, han, grown, forwarding, tie, mission, carotenoid, urged,
# Nearest to quite: dih, gop, greeks, corum, hearsay, spice, author, wales,
# Nearest to issue: exercise, call, harm, animators, didn, review, increase, ietf,
# Nearest to running: pc, throw, monster, sample, built, capability, dressed, sequenced,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.0435 0.2948 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.0022 0.2912 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 3.9713 0.2758 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.0188 0.2782 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.0136 0.3050 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.0682 0.3078 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.0360 0.2907 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.0702 0.2831 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 3.9921 0.2831 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.0652 0.2850 sec/batch
# Nearest to most: allegiance, recognition, others, macedonia, leather, among, tea, beneath,
# Nearest to three: approximately, withholding, millennium, disfellowshipped, sr, vieri, inadvertent, apricots,
# Nearest to no: accordance, question, nothing, spitfire, hypothesis, said, teilhard, witnessed,
# Nearest to over: hours, wakizashi, every, up, disruptions, footballer, years, allah,
# Nearest to b: calligraphy, projects, philosopher, judges, grainger, pirates, notebooks, mindat,
# Nearest to in: at, twice, purchase, metropolitan, throughout, turkish, nominal, public,
# Nearest to other: several, others, baldwin, importantly, reopen, colored, generation, canonical,
# Nearest to however: although, but, requirement, since, that, proved, trains, eccentric,
# Nearest to pre: discharging, radical, yet, traditions, genocide, moderate, lichen, nervous,
# Nearest to joseph: ben, bomis, enlightenment, projectors, reserved, arsenide, bellows, charted,
# Nearest to additional: computers, sale, soleil, kg, beam, instrument, devices, working,
# Nearest to placed: thro, pressure, metabolism, litigant, fleet, lands, submarine, close,
# Nearest to stage: han, look, grown, forwarding, tie, mission, urged, carotenoid,
# Nearest to quite: dih, gop, greeks, author, hearsay, spice, wales, corum,
# Nearest to issue: exercise, call, harm, review, animators, didn, telescope, ietf,
# Nearest to running: pc, throw, built, sample, sequenced, dressed, rie, capability,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.0221 0.2861 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.0435 0.2850 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.0307 0.2855 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.0421 0.2729 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.0503 0.2735 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.0385 0.2713 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.0632 0.2746 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.0530 0.2721 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.0400 0.2726 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.0191 0.2735 sec/batch
# Nearest to most: allegiance, macedonia, recognition, among, others, leather, remains, tea,
# Nearest to three: approximately, withholding, millennium, sr, vieri, disfellowshipped, inadvertent, peking,
# Nearest to no: accordance, question, nothing, spitfire, hypothesis, said, teilhard, witnessed,
# Nearest to over: hours, wakizashi, disruptions, up, every, footballer, increasing, allah,
# Nearest to b: calligraphy, judges, projects, grainger, mindat, pirates, notebooks, philosopher,
# Nearest to in: at, twice, purchase, metropolitan, turkish, public, throughout, holland,
# Nearest to other: several, baldwin, others, various, colored, canonical, reopen, generation,
# Nearest to however: although, but, since, that, requirement, proved, though, eccentric,
# Nearest to pre: discharging, radical, genocide, yet, md, traditions, lichen, retirees,
# Nearest to joseph: ben, bomis, projectors, enlightenment, arsenide, bellows, reserved, ought,
# Nearest to additional: sale, computers, soleil, kg, beam, matches, instrument, devices,
# Nearest to placed: thro, pressure, metabolism, litigant, fleet, submarine, standing, lands,
# Nearest to stage: han, look, forwarding, grown, mission, urged, carotenoid, tie,
# Nearest to quite: dih, gop, greeks, author, spice, wales, hearsay, originally,
# Nearest to issue: exercise, call, harm, review, animators, farther, telescope, amf,
# Nearest to running: pc, built, throw, dressed, sequenced, rie, monster, asr,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.0421 0.2762 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.0401 0.2736 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.0448 0.2740 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.0338 0.2730 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.0138 0.2726 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.0613 0.2742 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 3.9858 0.2717 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.0383 0.2753 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.0209 0.2717 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.0698 0.2738 sec/batch
# Nearest to most: allegiance, macedonia, recognition, danson, others, tea, leather, among,
# Nearest to three: approximately, withholding, millennium, attendance, disfellowshipped, vieri, sr, range,
# Nearest to no: accordance, question, nothing, spitfire, hypothesis, said, teilhard, little,
# Nearest to over: hours, wakizashi, disruptions, allah, every, up, increasing, footballer,
# Nearest to b: calligraphy, judges, pirates, mindat, projects, grainger, notebooks, alpha,
# Nearest to in: at, twice, metropolitan, purchase, public, turkish, throughout, holland,
# Nearest to other: others, several, baldwin, reopen, various, colored, canonical, generation,
# Nearest to however: although, but, since, that, requirement, proved, though, trains,
# Nearest to pre: discharging, genocide, radical, md, yet, traditions, lichen, retirees,
# Nearest to joseph: ben, ought, bomis, enlightenment, arsenide, projectors, bellows, friends,
# Nearest to additional: sale, soleil, computers, beam, kg, matches, instrument, goebbels,
# Nearest to placed: thro, pressure, metabolism, litigant, hobo, submarine, fleet, standing,
# Nearest to stage: han, look, forwarding, grown, mission, carotenoid, ballot, night,
# Nearest to quite: dih, gop, hearsay, spice, greeks, corum, author, wales,
# Nearest to issue: exercise, harm, call, review, animators, farther, telescope, didn,
# Nearest to running: pc, built, throw, capability, dressed, rie, hour, asr,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 3.8958 0.2752 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 3.6522 0.2689 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 3.8421 0.2697 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 3.9010 0.2732 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 3.9941 0.2742 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 3.9929 0.2728 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.0117 0.2736 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.0390 0.2710 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.0279 0.2737 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.0208 0.2724 sec/batch
# Nearest to most: allegiance, macedonia, among, others, recognition, leather, tea, remains,
# Nearest to three: approximately, withholding, millennium, disfellowshipped, attendance, vieri, peking, inadvertent,
# Nearest to no: accordance, question, nothing, spitfire, said, hypothesis, witnessed, little,
# Nearest to over: hours, wakizashi, disruptions, up, footballer, allah, every, increasing,
# Nearest to b: calligraphy, judges, projects, pirates, notebooks, grainger, mindat, kono,
# Nearest to in: at, twice, purchase, metropolitan, public, throughout, holland, sopot,
# Nearest to other: others, several, various, reopen, canonical, counting, colored, mice,
# Nearest to however: although, but, since, that, requirement, proved, though, reliable,
# Nearest to pre: discharging, genocide, md, radical, yet, lichen, retirees, berkshire,
# Nearest to joseph: ben, bomis, ought, arsenide, enlightenment, bellows, projectors, charted,
# Nearest to additional: soleil, sale, computers, beam, kg, matches, integrity, devices,
# Nearest to placed: thro, pressure, litigant, metabolism, submarine, standing, hobo, stood,
# Nearest to stage: han, look, forwarding, night, grown, carotenoid, ramp, mission,
# Nearest to quite: dih, gop, spice, hearsay, greeks, author, wales, corum,
# Nearest to issue: exercise, call, harm, review, animators, farther, increase, ietf,
# Nearest to running: pc, throw, built, hour, capability, dressed, rie, asr,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.0430 0.2775 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.0510 0.2729 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 3.9671 0.2730 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.0529 0.2711 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.0322 0.2715 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.0117 0.2693 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.0318 0.2690 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.0322 0.2732 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.0248 0.2753 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.0029 0.2719 sec/batch
# Nearest to most: macedonia, among, allegiance, tea, others, danson, recognition, harrier,
# Nearest to three: approximately, withholding, millennium, disfellowshipped, attendance, apricots, vieri, peking,
# Nearest to no: accordance, nothing, question, spitfire, said, hypothesis, little, witnessed,
# Nearest to over: hours, wakizashi, disruptions, increasing, up, years, footballer, inhabitants,
# Nearest to b: calligraphy, judges, mindat, projects, pirates, grainger, notebooks, kono,
# Nearest to in: metropolitan, purchase, twice, at, public, throughout, sopot, finlandization,
# Nearest to other: others, several, reopen, various, colored, austral, canonical, generation,
# Nearest to however: although, but, since, that, proved, requirement, though, eccentric,
# Nearest to pre: discharging, genocide, radical, md, yet, traditions, berkshire, lichen,
# ...
# Epoch 4/10 Iteration: 40100 Avg. Training loss: 4.0302 0.2746 sec/batch
# Epoch 4/10 Iteration: 40200 Avg. Training loss: 4.0149 0.2707 sec/batch
# Epoch 4/10 Iteration: 40300 Avg. Training loss: 4.0080 0.2717 sec/batch
# Epoch 4/10 Iteration: 40400 Avg. Training loss: 4.0256 0.2706 sec/batch
# Epoch 4/10 Iteration: 40500 Avg. Training loss: 4.0294 0.2702 sec/batch
# Epoch 4/10 Iteration: 40600 Avg. Training loss: 4.0021 0.2690 sec/batch
# Epoch 4/10 Iteration: 40700 Avg. Training loss: 3.9914 0.2685 sec/batch
# Epoch 4/10 Iteration: 40800 Avg. Training loss: 3.9556 0.2689 sec/batch
# Epoch 4/10 Iteration: 40900 Avg. Training loss: 4.0106 0.2706 sec/batch
# Epoch 4/10 Iteration: 41000 Avg. Training loss: 4.0141 0.2684 sec/batch
# Nearest to most: among, more, allegiance, imperialism, harrier, remains, extremely, danson,
# Nearest to three: approximately, withholding, vieri, disfellowshipped, inadvertent, peking, leisurely, attendance,
# Nearest to no: little, nothing, spitfire, accordance, witnessed, teilhard, said, bloomberg,
# Nearest to over: wakizashi, runways, surrealistic, increasing, disruptions, footballer, trotsky, around,
# Nearest to b: calligraphy, judges, projects, notebooks, mindat, grainger, kono, muppet,
# Nearest to in: finlandization, throughout, sopot, twice, public, purchase, musschenbroek, enhancers,
# Nearest to other: others, various, several, reopen, evangelistic, colored, horizontally, scientology,
# Nearest to however: although, but, though, that, since, requirement, eccentric, proved,
# Nearest to pre: discharging, genocide, rigours, guru, snatchers, xiong, suspension, identification,
# Nearest to joseph: ben, bomis, ought, arsenide, enlightenment, charted, projectors, bellows,
# Nearest to additional: soleil, matches, points, sale, symbols, obrenovi, computers, beam,
# Nearest to placed: thro, litigant, hobo, recounts, pressure, standing, depending, reforestation,
# Nearest to stage: forwarding, ballot, night, miriam, tie, look, fallacious, carotenoid,
# Nearest to quite: wales, hearsay, spice, semimajor, jer, author, corum, used,
# Nearest to issue: review, harm, farther, exercise, animators, question, call, separately,
# Nearest to running: pc, throw, capability, asr, dressed, rie, back, stash,
# Epoch 4/10 Iteration: 41100 Avg. Training loss: 3.9812 0.2729 sec/batch
# Epoch 4/10 Iteration: 41200 Avg. Training loss: 4.0474 0.2699 sec/batch
# Epoch 4/10 Iteration: 41300 Avg. Training loss: 4.0297 0.2703 sec/batch
# Epoch 4/10 Iteration: 41400 Avg. Training loss: 3.9937 0.2694 sec/batch
# Epoch 4/10 Iteration: 41500 Avg. Training loss: 4.0355 0.2712 sec/batch
# Epoch 4/10 Iteration: 41600 Avg. Training loss: 3.9826 0.2690 sec/batch
# Epoch 4/10 Iteration: 41700 Avg. Training loss: 4.0296 0.2699 sec/batch
# Epoch 4/10 Iteration: 41800 Avg. Training loss: 4.0174 0.2712 sec/batch
# Epoch 4/10 Iteration: 41900 Avg. Training loss: 3.9982 0.2698 sec/batch
# Epoch 4/10 Iteration: 42000 Avg. Training loss: 4.0054 0.2704 sec/batch
# Nearest to most: among, more, allegiance, imperialism, remains, harrier, extremely, many,
# Nearest to three: approximately, withholding, vieri, inadvertent, disfellowshipped, peking, apricots, millennium,
# Nearest to no: little, nothing, spitfire, accordance, teilhard, said, witnessed, rajiv,
# Nearest to over: runways, wakizashi, surrealistic, increasing, landen, around, footballer, disruptions,
# Nearest to b: calligraphy, judges, mindat, projects, notebooks, grainger, pirates, predynastic,
# Nearest to in: sopot, finlandization, throughout, twice, musschenbroek, public, reflect, biblioth,
# Nearest to other: others, various, several, reopen, signs, evangelistic, beds, scientology,
# Nearest to however: although, but, though, that, since, requirement, proved, eccentric,
# Nearest to pre: discharging, genocide, rigours, guru, julius, roundheads, snatchers, suspension,
# Nearest to joseph: ben, bomis, ought, enlightenment, arsenide, projectors, charted, bellows,
# Nearest to additional: soleil, matches, points, sale, symbols, obrenovi, kg, cosmogenic,
# Nearest to placed: thro, litigant, hobo, recounts, depending, reforestation, standing, pressure,
# Nearest to stage: forwarding, night, ballot, miriam, tie, relaying, fallacious, look,
# Nearest to quite: wales, hearsay, author, semimajor, spice, used, corum, dih,
# Nearest to issue: review, harm, farther, exercise, animators, question, call, manukau,
# Nearest to running: pc, throw, capability, asr, dressed, rie, back, stash,
# Epoch 4/10 Iteration: 42100 Avg. Training loss: 4.0222 0.2728 sec/batch
# Epoch 4/10 Iteration: 42200 Avg. Training loss: 4.0135 0.2700 sec/batch
# Epoch 4/10 Iteration: 42300 Avg. Training loss: 4.0104 0.2690 sec/batch
# Epoch 4/10 Iteration: 42400 Avg. Training loss: 3.9356 0.2682 sec/batch
# Epoch 4/10 Iteration: 42500 Avg. Training loss: 4.0075 0.2701 sec/batch
# Epoch 4/10 Iteration: 42600 Avg. Training loss: 3.9490 0.2674 sec/batch
# Epoch 4/10 Iteration: 42700 Avg. Training loss: 4.0441 0.2705 sec/batch
# Epoch 4/10 Iteration: 42800 Avg. Training loss: 4.0105 0.2684 sec/batch
# Epoch 4/10 Iteration: 42900 Avg. Training loss: 4.0372 0.2688 sec/batch
# Epoch 4/10 Iteration: 43000 Avg. Training loss: 3.9688 0.2679 sec/batch
# Nearest to most: among, more, allegiance, imperialism, remains, harrier, many, macedonia,
# Nearest to three: approximately, withholding, apricots, vieri, disfellowshipped, inadvertent, peking, patti,
# Nearest to no: little, nothing, spitfire, accordance, teilhard, evidence, bloomberg, ims,
# Nearest to over: runways, wakizashi, increasing, footballer, trotsky, surrealistic, landen, disruptions,
# Nearest to b: calligraphy, judges, projects, mindat, notebooks, muppet, grainger, kono,
# Nearest to in: finlandization, throughout, sopot, metropolitan, biblioth, twice, musschenbroek, purchase,
# Nearest to other: others, several, various, reopen, signs, hadn, midge, beds,
# Nearest to however: although, but, though, that, since, requirement, ehr, eccentric,
# Nearest to pre: discharging, genocide, rigours, guru, identification, snatchers, roundheads, suspension,
# Nearest to joseph: ben, bomis, enlightenment, ought, projectors, arsenide, charted, bellows,
# Nearest to additional: soleil, matches, sale, points, obrenovi, kg, beam, cosmogenic,
# Nearest to placed: thro, litigant, hobo, recounts, depending, reforestation, lands, pressure,
# Nearest to stage: forwarding, night, ballot, tie, miriam, han, relaying, look,
# Nearest to quite: hearsay, wales, used, spice, jer, semimajor, author, corum,
# Nearest to issue: review, harm, farther, exercise, animators, question, manukau, call,
# Nearest to running: throw, pc, dressed, capability, asr, rie, cessation, back,
# Epoch 4/10 Iteration: 43100 Avg. Training loss: 4.0485 0.2713 sec/batch
# Epoch 4/10 Iteration: 43200 Avg. Training loss: 4.0127 0.2689 sec/batch
# Epoch 4/10 Iteration: 43300 Avg. Training loss: 4.0099 0.2691 sec/batch
# Epoch 4/10 Iteration: 43400 Avg. Training loss: 4.0096 0.2705 sec/batch
# Epoch 4/10 Iteration: 43500 Avg. Training loss: 4.0347 0.2709 sec/batch
# Epoch 4/10 Iteration: 43600 Avg. Training loss: 3.9923 0.2695 sec/batch
# Epoch 4/10 Iteration: 43700 Avg. Training loss: 4.0042 0.2699 sec/batch
# Epoch 4/10 Iteration: 43800 Avg. Training loss: 4.0250 0.2699 sec/batch
# Epoch 4/10 Iteration: 43900 Avg. Training loss: 4.0168 0.2701 sec/batch
# Epoch 4/10 Iteration: 44000 Avg. Training loss: 4.0112 0.2704 sec/batch
# Nearest to most: more, among, imperialism, allegiance, remains, many, harrier, less,
# Nearest to three: approximately, withholding, vieri, apricots, inadvertent, millennium, peking, disfellowshipped,
# Nearest to no: little, nothing, spitfire, accordance, teilhard, evidence, bloomberg, ims,
# Nearest to over: runways, wakizashi, increasing, surrealistic, footballer, suppressant, trotsky, disruptions,
# Nearest to b: judges, calligraphy, projects, mindat, pirates, grainger, notebooks, kono,
# Nearest to in: finlandization, throughout, sopot, biblioth, public, metropolitan, musschenbroek, twice,
# Nearest to other: others, various, several, reopen, beds, signs, hadn, midge,
# Nearest to however: although, but, though, that, since, requirement, eccentric, proved,
# Nearest to pre: discharging, genocide, guru, snatchers, julius, roundheads, identification, rigours,
# Nearest to joseph: ben, ought, bomis, enlightenment, arsenide, projectors, bellows, samir,
# Nearest to additional: soleil, matches, sale, points, obrenovi, kg, cosmogenic, ilyushin,
# Nearest to placed: thro, litigant, hobo, recounts, depending, lands, standing, reforestation,
# Nearest to stage: forwarding, night, ballot, tie, look, han, miriam, relaying,
# Nearest to quite: hearsay, wales, used, spice, jer, very, semimajor, it,
# Nearest to issue: review, harm, farther, exercise, animators, question, call, manukau,
# Nearest to running: pc, dressed, capability, throw, asr, rie, cessation, logicians,
# Epoch 4/10 Iteration: 44100 Avg. Training loss: 4.0267 0.2719 sec/batch
# Epoch 4/10 Iteration: 44200 Avg. Training loss: 4.0177 0.2695 sec/batch
# Epoch 4/10 Iteration: 44300 Avg. Training loss: 4.0094 0.2731 sec/batch
# Epoch 4/10 Iteration: 44400 Avg. Training loss: 4.0213 0.2707 sec/batch
# Epoch 4/10 Iteration: 44500 Avg. Training loss: 3.9981 0.2708 sec/batch
# Epoch 4/10 Iteration: 44600 Avg. Training loss: 3.9879 0.2693 sec/batch
# Epoch 4/10 Iteration: 44700 Avg. Training loss: 4.0285 0.2710 sec/batch
# Epoch 4/10 Iteration: 44800 Avg. Training loss: 3.9655 0.2711 sec/batch
# Epoch 4/10 Iteration: 44900 Avg. Training loss: 4.0244 0.2723 sec/batch
# Epoch 4/10 Iteration: 45000 Avg. Training loss: 4.0068 0.2700 sec/batch
# Nearest to most: more, among, allegiance, remains, imperialism, harrier, many, less,
# Nearest to three: approximately, withholding, apricots, vieri, inadvertent, disfellowshipped, peking, millennium,
# Nearest to no: little, nothing, spitfire, accordance, teilhard, evidence, bloomberg, said,
# Nearest to over: runways, wakizashi, increasing, surrealistic, suppressant, disruptions, landen, around,
# Nearest to b: calligraphy, judges, mindat, projects, pirates, grainger, notebooks, multiplication,
# Nearest to in: finlandization, sopot, throughout, metropolitan, biblioth, public, reflect, jehovah,
# Nearest to other: others, various, several, reopen, midge, hadn, colored, beds,
# Nearest to however: although, but, though, that, since, requirement, reliable, ways,
# Nearest to pre: discharging, genocide, snatchers, guru, roundheads, rigours, julius, suspension,
# Nearest to joseph: ben, ought, bomis, enlightenment, arsenide, projectors, bellows, charted,
# Nearest to additional: soleil, matches, points, sale, obrenovi, cosmogenic, symbols, integrity,
# Nearest to placed: thro, litigant, hobo, recounts, depending, reforestation, pressure, standing,
# Nearest to stage: forwarding, night, ballot, tie, miriam, look, relaying, fallacious,
# Nearest to quite: hearsay, wales, used, very, jer, it, semimajor, spice,
# Nearest to issue: review, harm, farther, exercise, animators, question, manukau, call,
# Nearest to running: pc, dressed, capability, asr, throw, rie, logicians, stash,
# Epoch 4/10 Iteration: 45100 Avg. Training loss: 4.0393 0.2741 sec/batch
# Epoch 4/10 Iteration: 45200 Avg. Training loss: 3.9012 0.2692 sec/batch
# Epoch 4/10 Iteration: 45300 Avg. Training loss: 3.6178 0.2655 sec/batch
# Epoch 4/10 Iteration: 45400 Avg. Training loss: 3.8676 0.2691 sec/batch
# Epoch 4/10 Iteration: 45500 Avg. Training loss: 3.8422 0.2680 sec/batch
# Epoch 4/10 Iteration: 45600 Avg. Training loss: 3.9771 0.2707 sec/batch
# Epoch 4/10 Iteration: 45700 Avg. Training loss: 3.9818 0.2711 sec/batch
# Epoch 4/10 Iteration: 45800 Avg. Training loss: 3.9965 0.2713 sec/batch
# Epoch 4/10 Iteration: 45900 Avg. Training loss: 4.0043 0.2719 sec/batch
# Epoch 4/10 Iteration: 46000 Avg. Training loss: 4.0115 0.2696 sec/batch
# Nearest to most: among, more, allegiance, imperialism, remains, many, less, harrier,
# Nearest to three: approximately, vieri, withholding, disfellowshipped, inadvertent, peking, apricots, leisurely,
# Nearest to no: little, nothing, spitfire, accordance, evidence, teilhard, said, bloomberg,
# Nearest to over: wakizashi, runways, footballer, trotsky, surrealistic, disruptions, increasing, around,
# Nearest to b: judges, calligraphy, projects, muppet, pirates, mindat, notebooks, kono,
# Nearest to in: finlandization, sopot, throughout, twice, public, enhancers, musschenbroek, metropolitan,
# Nearest to other: others, various, several, reopen, beds, canonical, scientology, horizontally,
# Nearest to however: although, but, though, that, since, requirement, because, eccentric,
# Nearest to pre: discharging, genocide, snatchers, guru, roundheads, xiong, julius, retirees,
# Nearest to joseph: ben, ought, bomis, arsenide, samir, enlightenment, charted, bellows,
# Nearest to additional: soleil, matches, points, obrenovi, sale, symbols, ilyushin, cosmogenic,
# Nearest to placed: thro, litigant, hobo, depending, reforestation, standing, recounts, reinsurance,
# Nearest to stage: night, forwarding, ballot, tie, actors, look, miriam, relaying,
# Nearest to quite: hearsay, wales, very, it, used, jer, spice, corum,
# Nearest to issue: review, harm, farther, exercise, question, animators, call, manukau,
# Nearest to running: dressed, pc, throw, asr, capability, stash, rie, cessation,
# Epoch 4/10 Iteration: 46100 Avg. Training loss: 4.0109 0.2739 sec/batch
# Epoch 4/10 Iteration: 46200 Avg. Training loss: 4.0220 0.2725 sec/batch
# Epoch 4/10 Iteration: 46300 Avg. Training loss: 4.0251 0.2718 sec/batch
# Epoch 4/10 Iteration: 46400 Avg. Training loss: 3.9561 0.2714 sec/batch
# Epoch 4/10 Iteration: 46500 Avg. Training loss: 4.0345 0.2708 sec/batch
# Epoch 4/10 Iteration: 46600 Avg. Training loss: 4.0018 0.2687 sec/batch
# Epoch 4/10 Iteration: 46700 Avg. Training loss: 3.9820 0.2729 sec/batch
# Epoch 4/10 Iteration: 46800 Avg. Training loss: 4.0132 0.2689 sec/batch
# Epoch 4/10 Iteration: 46900 Avg. Training loss: 4.0290 0.2725 sec/batch
# Epoch 4/10 Iteration: 47000 Avg. Training loss: 4.0169 0.2706 sec/batch
# Nearest to most: among, more, allegiance, remains, imperialism, less, harrier, many,
# Nearest to three: approximately, withholding, vieri, apricots, disfellowshipped, attendance, peking, inadvertent,
# Nearest to no: little, nothing, spitfire, accordance, evidence, teilhard, bloomberg, said,
# Nearest to over: runways, wakizashi, increasing, surrealistic, around, disruptions, trotsky, footballer,
# Nearest to b: judges, calligraphy, mindat, projects, predynastic, notebooks, pirates, grainger,
# Nearest to in: finlandization, sopot, throughout, enhancers, twice, public, purchase, jehovah,
# Nearest to other: others, various, several, reopen, horizontally, midge, colored, hadn,
# Nearest to however: although, but, though, that, since, requirement, ways, because,
# Nearest to pre: discharging, genocide, julius, snatchers, roundheads, guru, xiong, rigours,
# Nearest to joseph: ben, ought, bomis, arsenide, bellows, enlightenment, readme, netbios,
# Nearest to additional: soleil, matches, points, obrenovi, sale, kg, symbols, ilyushin,
# Nearest to placed: thro, litigant, hobo, recounts, standing, depending, lands, reforestation,
# Nearest to stage: forwarding, night, ballot, tie, relaying, fallacious, miriam, look,
# Nearest to quite: hearsay, wales, very, jer, it, used, semimajor, corum,
# Nearest to issue: review, harm, farther, exercise, question, animators, manukau, call,
# Nearest to running: pc, dressed, capability, throw, asr, rie, back, logicians,
# Epoch 4/10 Iteration: 47100 Avg. Training loss: 4.0137 0.2733 sec/batch
# Epoch 4/10 Iteration: 47200 Avg. Training loss: 3.8779 0.2685 sec/batch
# Epoch 4/10 Iteration: 47300 Avg. Training loss: 3.9735 0.2706 sec/batch
# Epoch 4/10 Iteration: 47400 Avg. Training loss: 3.9937 0.2734 sec/batch
# Epoch 4/10 Iteration: 47500 Avg. Training loss: 3.8910 0.2701 sec/batch
# Epoch 4/10 Iteration: 47600 Avg. Training loss: 3.9911 0.2702 sec/batch
# Epoch 4/10 Iteration: 47700 Avg. Training loss: 4.0259 0.2712 sec/batch
# Epoch 4/10 Iteration: 47800 Avg. Training loss: 3.9703 0.2690 sec/batch
# Epoch 4/10 Iteration: 47900 Avg. Training loss: 3.9640 0.2697 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: expected bytes, NoneType found
#
# During handling of the above exception, another exception occurred:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-120-4eeca6a379f0> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# D:\ProgramData\Miniconda3\envs\embeddings\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1455     logging.info("Restoring parameters from %s", save_path)
#    1456     sess.run(self.saver_def.restore_op_name,
# -> 1457              {self.saver_def.filename_tensor_name: save_path})
#    1458
#    1459   @staticmethod
#
# D:\ProgramData\Miniconda3\envs\embeddings\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\ProgramData\Miniconda3\envs\embeddings\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# D:\ProgramData\Miniconda3\envs\embeddings\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# D:\ProgramData\Miniconda3\envs\embeddings\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# D:\ProgramData\Miniconda3\envs\embeddings\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# SystemError: <built-in function TF_Run> returned a result with an error set

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
